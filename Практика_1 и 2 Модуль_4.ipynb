# %% [markdown]
# <a href="https://colab.research.google.com/github/nastya5517/The_whole_world_in_your_hands/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1%20%D0%B8%202%20%D0%9C%D0%BE%D0%B4%D1%83%D0%BB%D1%8C_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ПРАКТИКА №1

# %% [markdown]
# ##Задание №1

# %%
print( "Hello word")
# Out:
# Hello word

# %% [markdown]
# ##Задание №2

# %%
i = ("4 8 15 16 23 42")
print(i)
# Out:
# 4 8 15 16 23 42

# %% [markdown]
# ##Задание №3

# %%
a = "*"
print (a)
print (a*2)
print (a*3)
print (a*4)
print (a*5)
print (a*6)
print (a*7)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# ##Задание №4

# %%
print ("Отчет о доходах")
print ("1 квартал: 1200000 руб.\n2 квартал: 1350000 руб.\n3 квартал: 1280000 руб.\n4 квартал: 1420000 руб.")
# Out:
# Отчет о доходах
# 1 квартал: 1200000 руб.
# 2 квартал: 1350000 руб.
# 3 квартал: 1280000 руб.
# 4 квартал: 1420000 руб.

# %% [markdown]
# ##Задание №5

# %%
Name = input("Введите имя")
print("Добро пожаловать,", Name, "!")
# Out:
# Введите имяВлад
# Добро пожаловать, Влад !

# %% [markdown]
# ##Задание №6

# %%
m = input ("Введите название компании")
print (m, "- лидер рынка!")
# Out:
# Введите название компанииСбер
# Сбер - лидер рынка!

# %% [markdown]
# ##Задание №7

# %%
a = input ("Название")
b = input ("Число строк")
c = input ( "Число столбцов")
print (a)
print (b)
print (c)
# Out:
# НазваниеSales Q1
# Число строк1000
# Число столбцов8
# Sales Q1
# 1000
# 8

# %% [markdown]
# ##Задание №8

# %%
Отчет_1 = input ()
Отчет_2 = input()
Отчет_3 = input ()
print (Отчет_3)
print (Отчет_2)
print (Отчет_1)
# Out:
# Продажи за Январь
# Продажи за Февраль
# Продажи за Март
# Продажи за Март
# Продажи за Февраль
# Продажи за Январь

# %% [markdown]
# ##Задание №9

# %%
base_price = int (input())
growth_percent = int (input())
new_price = (base_price + (base_price*growth_percent/100))
delta = new_price - base_price
print ("new_price =", new_price)
print ("delta =", delta)
# Out:
# 100
# 20
# new_price = 120.0
# delta = 20.0

# %% [markdown]
# ##Задание №10

# %%
print ("Северный", "Центральный", "Южный", sep = "***")
# Out:
# Северный***Центральный***Южный

# %% [markdown]
# ##Задание №11

# %%
n = input ("name")
print ("Подключение установлено. Добро пожаловать,",n, end='!')
# Out:
# nameВлад
# Подключение установлено. Добро пожаловать, Влад!

# %% [markdown]
# ##Задание 12

# %%
a = input("Строка-разделитель")
b = input("Название товара 1")
c = input ("Название товара 2")
d = input ("Название товара 3")
print (b, c, d, sep = "|")
# Out:
# Строка-разделитель|
# Название товара 1Молоко
# Название товара 2Хлеб
# Название товара 3Сыр
# Молоко|Хлеб|Сыр

# %% [markdown]
# ##Задание 13

# %%
value_str = float (input())
integer_part = int (value_str)
print ("integer_part =" ,integer_part)
# Out:
# 42.7
# integer_part = 42

# %% [markdown]
# ##Задание 14

# %%
orders_yesterday = int (input())
plan = int (input())
Отклонение = abs (plan - orders_yesterday)
print ("Абсолютное отклонение от плана равняется", Отклонение)
# Out:
# 10
# 20
# Абсолютное отклонение от плана равняется 10

# %% [markdown]
# ##Задание №15

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())
list = [a, b, c, d, e]
maxim = max (list)
mini = min (list)
print ("Наибольшее число", maxim)
print ("Наименьшее число", mini)
# Out:
# 1
# 2
# 3
# 4
# 5
# Наибольшее число 5
# Наименьшее число 1

# %% [markdown]
# ##Задание №16

# %%
e = input ("Имя")
t = input ("Фамилия")
o = e + " "+ t
print ("Привет,", o, "! Вы только что начали изучать Python!")
# Out:
# ИмяАнтон
# ФамилияИванов
# Привет, Антон Иванов ! Вы только что начали изучать Python!

# %% [markdown]
# ##Задание №17

# %%
r = input ("Первая часть цитаты")
y = input ("Вторая часть цитаты")
s = r+y
print (s)
# Out:
# Первая часть цитатыКаждый в этой стране должен научиться программировать,
# Вторая часть цитатыпотому что это учит думать
# Каждый в этой стране должен научиться программировать,потому что это учит думать

# %% [markdown]
# ##Задание №18

# %%
w = int (input ("Сумма покупки"))
m = 1000
print (w>m)
# Out:
# Сумма покупки999
# False

# %% [markdown]
# ##Задание 19

# %%
q = int (input ("Возраст"))
x = 18
print (q>=18)
# Out:
# Возраст16
# False

# %% [markdown]
# ##Задание 20

# %%
s= int (input ("объем данных между потоками"))
v1 = int (input ("Скорость 1 потока"))
v2 = int (input ("Скорость 2 потока"))
t = s/(v1+v2)
print (t)
# Out:
# объем данных между потоками500
# Скорость 1 потока50
# Скорость 2 потока70
# 4.166666666666667

# %% [markdown]
# ##Задание 21

# %%
k1= int (input ("Длина первого катета"))
k2 = int (input ("Длина второго катета"))
s = k1*k2/2
print (s)
# Out:
# Длина первого катета443
# Длина второго катета390
# 86385.0

# %% [markdown]
# ##Задание 22

# %%
t = float (input ("Температура в градусах"))
f = 5/9*(t-32)
print (f)
# Out:
# Температура в градусах450.55
# 232.5277777777778

# %% [markdown]
# ##Задание 23

# %%
revenue_str = float(input ("Выручка за день"))
courier_name = input ("Имя курьера")
b = int (revenue_str/100)
print ("report = Курьер", courier_name, "получит бонус", b, "р.")
# Out:
# Выручка за день438746.78
# Имя курьераАнтон
# report = Курьер Антон получит бонус 4387 р.

# %% [markdown]
# #ПРАКТИКА 2

# %% [markdown]
# #Задание 1

# %%
a = input("Введите пароль")
b = input("Повторите пароль")
if a==b:
    print ("Пароль принят")
else:
    print ("Пароль не принят")
# Out:
# Введите парольqwerty
# Повторите парольQwerty
# Пароль не принят

# %% [markdown]
# #Задание 2

# %%
a = int(input("Введите возраст"))
if a >=18:
    print ("Доступ разрешен")
else:
    print ("Доступ запрещен")
# Out:
# Введите возраст77
# Доступ разрешен

# %% [markdown]
# #Задание 3

# %%
n = int(input("Введите первое число"))
m = int(input("Введите второе число"))
print (min(n,m))
# Out:
# Введите первое число8
# Введите второе число11
# 8

# %% [markdown]
# #Задание 4

# %%
a = int(input("Число первое"))
b = int(input("Число второе"))
c = int(input("Число третье"))
if b-a == c-b:
    print("Да")
else:
    print("Нет")
# Out:
# Число первое1
# Число второе2
# Число третье3
# Да

# %% [markdown]
# #Задание 5

# %%
a = int(input("Число первое"))
b = int(input("Число второе"))
c = int(input("Число третье"))
summa = a+b+c
counter = 0 + summa
if a> 0 and b>0 and c > 0:
    print(summa)
else:
    print (0)

print (counter)
# Out:
# Число первое5
# Число второе4
# Число третье3
# 12
# 12

# %% [markdown]
# #Задание 6

# %%
a = int(input("Число первое"))
b = int(input("Число второе"))
c = int(input("Число третье"))
s = int(input("Число четвертое"))
if a<b and a<c and a<s:
    print (a)
elif b<a and b<c and b<s:
    print (b)
elif c<a and c<b and c<s:
    print (c)
elif s<a and s<b and s<c:
    print (s)
# Out:
# Число первое5
# Число второе4
# Число третье8
# Число четвертое1
# 1

# %% [markdown]
# #Задание 7

# %%
year = int(input("Введите год"))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print ("Да")
else:
    print ("Н")
# Out:
# Введите год2020
# Да

# %% [markdown]
# #Задание 8

# %%
v = int(input("Число первое"))
q = int(input("Число второе"))
o = int(input("Число третье"))
if (v >= q and v <= o) or (v <= q and v >= o):
    print(v)
elif (q >= v and q <= o) or (q <= v and q >= o):
    print(q)
else:
    print(o)
# Out:
# Число первое1
# Число второе2
# Число третье3
# 2

# %% [markdown]
# #Задание 9

# %%
for v in range (10):
  print ("Войти в IT с Python")
# Out:
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python
# Войти в IT с Python

# %% [markdown]
# #Задание 10

# %%
n = int(input("Введите число n"))
if 1 <= n <= 20:
    for i in range(n):
        print("*" * 19)
# Out:
# Введите число n2
# *******************
# *******************

# %% [markdown]
# #Задание 11

# %%
v = input()
for i in range (10):
  print (i,v)
# Out:
# epoche
# 0 epoche
# 1 epoche
# 2 epoche
# 3 epoche
# 4 epoche
# 5 epoche
# 6 epoche
# 7 epoche
# 8 epoche
# 9 epoche

# %% [markdown]
# #Задание 12*

# %%
n = int(input())
m = (n+n)
v = (m+n)
s = (v+m)
d = (s+v)
w = (d+s)
if n <= 100:
  print (n, m, v, s, d, w)
# Out:
# 1
# 1 2 3 5 8 13

# %% [markdown]
# #Задание 13

# %%
n = int(input())
f = 1
for i in range(1, n + 1):
    f *= i
print(f)
# Out:
# 8
# 40320

# %% [markdown]
# #Задание 14

# %%
while True:
    n = input("1 слово: ")
    o = input("2 слово: ")
    if n == "стоп" or o == "стоп":
        break
    print(n, o)
# Out:
# 1 слово: первый
# 2 слово: второй
# первый второй
# 1 слово: первый
# 2 слово: стоп

# %% [markdown]
# #Задание 15

# %%
q = 0
n = int(input())

while n >= 0:
    q = q + n
    n = int(input())

print(q)
# Out:
# 7
# 7
# 7
# -3
# 21

# %% [markdown]
# #Задание 16

# %%
def draw_triangle():
    for i in range(1, 8):
        print('*' * i)

draw_triangle()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# #Задание №17

# %%
n = input("name")
a = input("surname")
s = input("patronic")
def print_fio(name, surname, patronic):
  result = surname [0] + name [0] + patronic [0]
  print(result)

print_fio(n, a, s)
# Out:
# nameАлексей
# surnameИванов
# patronicПетрович
# ИАП
