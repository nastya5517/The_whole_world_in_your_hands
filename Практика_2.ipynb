# %% [markdown]
# <a href="https://colab.research.google.com/github/nastya5517/The_whole_world_in_your_hands/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задача №1

# %%
base_price = int(input("Базовая цена"))
growth_percent = int (input ("Процент"))
new_price = base_price + base_price/100*growth_percent
delta = new_price - base_price
print ("Новая цена", new_price)
print ("Дельта", delta)
# Out:
# Базовая цена100
# Процент20
# Новая цена 120.0
# Дельта 20.0

# %%
base_price = int(input("Базовая цена"))
growth_percent = int (input ("Процент"))
new_price = base_price + base_price/100*growth_percent
delta = new_price - base_price
print ("Новая цена", new_price)
print ("Дельта", delta)
# Out:
# Базовая цена200
# Процент50
# Новая цена 300.0
# Дельта 100.0

# %%
base_price = int(input("Базовая цена"))
growth_percent = int (input ("Процент"))
new_price = base_price + base_price/100*growth_percent
delta = new_price - base_price
print ("Новая цена", new_price)
print ("Дельта", delta)
# Out:
# Базовая цена75
# Процент10
# Новая цена 82.5
# Дельта 7.5

# %%
base_price = float(input("Базовая цена"))
growth_percent = int (input ("Процент"))
new_price = base_price + base_price/100*growth_percent
delta = new_price - base_price
print ("Новая цена", new_price)
print ("Дельта", delta)
# Out:
# Базовая цена123.45
# Процент15
# Новая цена 141.9675
# Дельта 18.5175

# %%
base_price = int(input("Базовая цена"))
growth_percent = int (input ("Процент"))
new_price = base_price + base_price/100*growth_percent
delta = new_price - base_price
print ("Новая цена", new_price)
print ("Дельта", delta)
# Out:
# Базовая цена25
# Процент0
# Новая цена 25.0
# Дельта 0.0

# %% [markdown]
# #Задача 2

# %%
orders_today = 17
orders_yesterday = 10
city_name = "New_York"
total_orders = orders_yesterday + orders_today
print("Total_orders = ", total_orders)

full_label = "Город " + city_name
print (full_label)

more_orders_today = orders_today > orders_yesterday
print ("more_orders_today =", more_orders_today)

big_day = orders_today > 1000
print ("big_day =", big_day)
# Out:
# Total_orders =  27
# Город New_York
# more_orders_today = True
# big_day = False

# %% [markdown]
# #Задача №3

# %%
total_minutes = 135
hours = total_minutes//60
minutes = total_minutes%60
print ("hourse =", hours)
print ("minutes =", minutes)
# Out:
# hourse = 2
# minutes = 15

# %% [markdown]
# #Задача №4

# %%
value_str = "42.7"
i = float(value_str)
integer_part = int (i)
print (integer_part)
# Out:
# 42

# %%
#Задача 5 ПЕРВАЯ

# %%
orders_yesterday = 10
plan = 20
abs_diff = abs(plan - orders_yesterday)
print("abs_diff =", abs_diff)

report = ("Абсолютное отклонение от плана равняется")
print (report, abs_diff)
# Out:
# abs_diff = 10
# Абсолютное отклонение от плана равняется 10

# %%
orders_yesterday = 11
plan = 5
abs_diff = abs(plan - orders_yesterday)
print("abs_diff =", abs_diff)

report = ("Абсолютное отклонение от плана равняется")
print (report, abs_diff)
# Out:
# abs_diff = 6
# Абсолютное отклонение от плана равняется 6

# %% [markdown]
# #Задача 5 ВТОРАЯ
