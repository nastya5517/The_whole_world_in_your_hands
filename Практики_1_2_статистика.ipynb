# %% [markdown]
# <a href="https://colab.research.google.com/github/nastya5517/The_whole_world_in_your_hands/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B8_1_2_%D1%81%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Работа с данными
import pandas as pd
import numpy as np

# Визуализация
import matplotlib.pyplot as plt
import seaborn as sns

# Машинное обучение
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)

# %% [markdown]
# Ниже перечислены все библиотеки, которые применяются в работе, и их назначение.
#
# **1. pandas**
# Используется для загрузки, хранения и обработки табличных данных
# (чтение, фильтрация, статистика, работа с колонками).
#
# **2. numpy**
# Базовая библиотека для численных вычислений: массивы, математические операции.
#
# **3. matplotlib.pyplot**
# Основная библиотека для построения графиков (линейные графики, гистограммы, scatter-плоты).
#
# **4. seaborn**
# Надстройка над matplotlib.
# Позволяет строить более красивые и информативные графики (heatmap, pairplot, regplot и т.д.).
#
# **5. scikit-learn (sklearn)**
# Используется для построения моделей машинного обучения.
#
# *Основные модули:*
#
# - **train_test_split** — разделение данных на обучающую и тестовую выборки;
# - **StandardScaler** — нормализация признаков;
# - **LinearRegression** — линейная регрессия;
# - **r2_score, mean_absolute_error, mean_squared_error** — оценка качества модели;
# - другие инструменты для предсказаний и анализа.

# %%
# Загрузка файла
df = pd.read_csv("/content/drive/MyDrive/Итоговый проект/heart3.csv")
df
# Out:
#      Возраст алког  Работа  Переломы  Время пробуждения  ЛПВП  \
# 0             18.0       1         0                  6  0.97
# 1             90.0       0         1                  4  0.74
# 2             17.0       0         0                  7  1.57
# 3             13.0       1         0                  7  0.68
# 4             16.0       0         1                  6  1.01
# ..             ...     ...       ...                ...   ...
# 944           18.0       1         1                  6  0.90
# 945           26.0       1         0                  7  1.24
# 946           20.0       0         0                  8  1.01
# 947           21.0       1         0                  8  1.74
# 948           17.0       1         1                  5  0.82
#
#      Выход на пенсию  Холестерин  Артериальная гипертония  Триглицериды  \
# 0                  0         4.0                        0          0.52
# 1                  0         8.6                        0          2.73
# 2                  0         5.2                        0          1.02
# 3                  0         4.9                        1          3.25
# 4                  0         8.2                        1          1.25
# ..               ...         ...                      ...           ...
# 944                0         4.6                        0          0.75
# 945                0         4.3                        0          0.57
# 946                1         5.9                        1          3.54
# 947                0         4.6                        0          0.63
# 948                0         4.9                        0          1.20
#
#      Гепатит  ...  Сон после обеда  Время засыпания  \
# 0          0  ...                0               10
# 1          0  ...                1               12
# 2          0  ...                0               11
# 3          0  ...                0               11
# 4          1  ...                0               11
# ..       ...  ...              ...              ...
# 944        0  ...                0               10
# 945        0  ...                0                9
# 946        0  ...                1               10
# 947        1  ...                0               11
# 948        0  ...                1               10
#
#      Хроническое заболевание легких  Сигарет в день  Образование  \
# 0                                 0            20.0            3
# 1                                 0             0.0            5
# 2                                 0             0.0            5
# 3                                 0            10.0            3
# 4                                 0             0.0            3
# ..                              ...             ...          ...
# 944                               0            20.0            4
# 945                               0            10.0            3
# 946                               0            10.0            3
# 947                               0             0.0            5
# 948                               0            30.0            4
#
#      Индекс массы тела, кг/м^2     Религия   Профессия  ССЗ  \
# 0                         25.1  799.035538  136.025100    0
# 1                         35.2  799.078379  224.056407    1
# 2                         19.0  799.055423  224.035858    0
# 3                         31.6   85.000523  136.065663    1
# 4                         32.8  799.076099   72.024040    1
# ..                         ...         ...         ...  ...
# 944                       27.1  799.091843   72.006723    0
# 945                       26.0  799.095093  136.059485    0
# 946                       27.8  799.057712   89.073887    1
# 947                       23.1   85.035712   35.003244    0
# 948                       27.6  799.078755   72.065872    1
#
#      Продолжительность сна
# 0                        8
# 1                        4
# 2                        8
# 3                        8
# 4                        7
# ..                     ...
# 944                      8
# 945                     10
# 946                     10
# 947                      9
# 948                      7
#
# [949 rows x 32 columns]

# %% [markdown]
# # Описательные статистики

# %% [markdown]
# ### **Центральные тенденции**
#
# Для всех числовых признаков вычислите:
#
# - среднее (mean);
# - медиану (median);
# - моду (mode).
#
#
# ---
#
#
# Оформите всё в виде таблицы.
# Сделайте вывод: где среднее и медиана различаются сильнее всего.

# %%
mean_vals = df.mean(numeric_only=True)
median_vals = df.median(numeric_only=True) # допишите код
mode_vals = df.mode(numeric_only=True).iloc[0] # допишите код

summary = pd.DataFrame({
    "Среднее": mean_vals, # допишите код
    "Медиана": median_vals , # допишите код
    "Мода": mode_vals
})

summary
# Out:
#                                            Среднее     Медиана        Мода
# Возраст алког                            32.206533   20.000000   20.000000
# Работа                                    0.523709    1.000000    1.000000
# Переломы                                  0.353003    0.000000    0.000000
# Время пробуждения                         6.819810    7.000000    6.000000
# ЛПВП                                      1.070095    1.110000    1.180000
# Выход на пенсию                           0.335090    0.000000    0.000000
# Холестерин                                5.868599    5.200000    5.000000
# Артериальная гипертония                   0.485774    0.000000    0.000000
# Триглицериды                              2.043393    1.480000    0.710000
# Гепатит                                   0.121180    0.000000    0.000000
# Сахарный диабет                           0.105374    0.000000    0.000000
# Пол                                       0.700738    1.000000    1.000000
# Спорт, клубы                              0.068493    0.000000    0.000000
# Семья                                   375.302051  559.014866    2.032866
# Частота пасс кур                          0.615385    0.000000    0.000000
# Возраст курения                          60.059009   90.000000   90.000000
# Травмы за год                             0.053741    0.000000    0.000000
# Регулярный прием лекарственных средств    0.641728    1.000000    1.000000
# Национальность                          844.557542  895.048785    1.004157
# Алкоголь                                472.920760  631.023829  155.000909
# Глюкоза плазмы натощак                    6.670126    6.000000    4.290000
# Абдоминальное ожирение, см               80.162487   81.400000   68.300000
# Сон после обеда                           0.225501    0.000000    0.000000
# Время засыпания                          11.140148   11.000000   11.000000
# Хроническое заболевание легких            0.075869    0.000000    0.000000
# Сигарет в день                            5.886196    0.000000    0.000000
# Образование                               4.124341    4.000000    4.000000
# Индекс массы тела, кг/м^2                28.175869   27.600000   23.300000
# Религия                                 682.750558  799.040754   24.012056
# Профессия                               125.584941  123.007116    5.048727
# ССЗ                                       0.548999    1.000000    1.000000
# Продолжительность сна                     7.679663    8.000000    7.000000

# %% [markdown]
# **Выводы (дописать):**
#
# По результатам расчёта среднего, медианы и моды видно, что для многих признаков среднее и медиана существенно отличаются, например, **Возраст алког** и **Возраст курения**. Это обычно говорит о ненормальном распределении данных.
#
#
# Такие расхождения подтверждают, что данные содержат признаки с **асимметричными распределениями**, где среднее — неустойчивый показатель, а медиана лучше отражает реальное «центральное» значение.

# %% [markdown]
# ### **Разброс данных**
#
# Вычислите:
#
# - стандартное отклонение (std);
# - дисперсию (var);
# - коэффициент вариации;
# - размах значений.
#
# Оформите результат в таблицу.
# Сделайте вывод: какие признаки имеют наибольший разброс значений.

# %%
std_vals = df.std(numeric_only=True) # допишите код
var_vals = df.var(numeric_only=True) # допишите код
cv_vals = df.std(numeric_only=True) / df.mean(numeric_only=True)
range_vals = df.max(numeric_only=True) - df.min(numeric_only=True)

dispersion_summary = pd.DataFrame({
    "Стандртное отклонение": std_vals,
    "Дисперсия": var_vals, # допишите код
    "Коэффициент вариации": cv_vals, # допишите код
    "Размах": range_vals
})

dispersion_summary
# Out:
#                                         Стандртное отклонение     Дисперсия  \
# Возраст алког                                       26.942616    725.904556
# Работа                                               0.499701      0.249701
# Переломы                                             0.478156      0.228633
# Время пробуждения                                    1.364942      1.863067
# ЛПВП                                                 0.368732      0.135963
# Выход на пенсию                                      0.472271      0.223040
# Холестерин                                           1.667100      2.779224
# Артериальная гипертония                              0.500061      0.250061
# Триглицериды                                         1.704405      2.904996
# Гепатит                                              0.326509      0.106608
# Сахарный диабет                                      0.307197      0.094370
# Пол                                                  0.458176      0.209926
# Спорт, клубы                                         0.252723      0.063869
# Семья                                              221.203071  48930.798478
# Частота пасс кур                                     1.358135      1.844531
# Возраст курения                                     34.897086   1217.806641
# Травмы за год                                        0.225624      0.050906
# Регулярный прием лекарственных средств               0.479745      0.230156
# Национальность                                     205.678628  42303.698161
# Алкоголь                                           222.876252  49673.823748
# Глюкоза плазмы натощак                               2.863944      8.202173
# Абдоминальное ожирение, см                          12.234499    149.682958
# Сон после обеда                                      0.418132      0.174834
# Время засыпания                                      1.165774      1.359030
# Хроническое заболевание легких                       0.264929      0.070187
# Сигарет в день                                       9.105321     82.906866
# Образование                                          0.730100      0.533046
# Индекс массы тела, кг/м^2                            4.825009     23.280715
# Религия                                            268.745640  72224.218969
# Профессия                                           60.887692   3707.311077
# ССЗ                                                  0.497856      0.247860
# Продолжительность сна                                1.507582      2.272803
#
#                                         Коэффициент вариации      Размах
# Возраст алког                                       0.836557   84.000000
# Работа                                              0.954157    1.000000
# Переломы                                            1.354537    1.000000
# Время пробуждения                                   0.200144   12.000000
# ЛПВП                                                0.344579    2.470000
# Выход на пенсию                                     1.409386    1.000000
# Холестерин                                          0.284071    5.600000
# Артериальная гипертония                             1.029410    1.000000
# Триглицериды                                        0.834105   14.090000
# Гепатит                                             2.694406    1.000000
# Сахарный диабет                                     2.915297    1.000000
# Пол                                                 0.653849    1.000000
# Спорт, клубы                                        3.689762    1.000000
# Семья                                               0.589400  557.067105
# Частота пасс кур                                    2.206970    5.000000
# Возраст курения                                     0.581047   85.000000
# Травмы за год                                       4.198383    1.000000
# Регулярный прием лекарственных средств              0.747584    1.000000
# Национальность                                      0.243534  894.095784
# Алкоголь                                            0.471276  476.098971
# Глюкоза плазмы натощак                              0.429369   23.980000
# Абдоминальное ожирение, см                          0.152621   51.600000
# Сон после обеда                                     1.854239    1.000000
# Время засыпания                                     0.104646   15.000000
# Хроническое заболевание легких                      3.491906    1.000000
# Сигарет в день                                      1.546894   40.000000
# Образование                                         0.177022    3.000000
# Индекс массы тела, кг/м^2                           0.171246   19.000000
# Религия                                             0.393622  775.087779
# Профессия                                           0.484833  219.050997
# ССЗ                                                 0.906843    1.000000
# Продолжительность сна                               0.196308   19.000000

# %% [markdown]
# **Выводы (дописать):**
#
# Разброс значений в датасете сильно различается между признаками.
#
# Наибольшую изменчивость показывают переменные "Семья", "Возраст алкг",
# "Возраст курения", "Национальность", "Алкоголь", "Религия", "Профессия". Их значения распределены очень неравномерно.
#
# Наименьший разброс наблюдается у "Переломы", "Образование", "ССЗ", "ЛПВП", "Сон после обеда", "Время засыпания",
#
# В целом, признаки с большим разбросом требуют нормализации перед моделированием, чтобы избежать доминирования над переменными с низкой вариативностью.

# %% [markdown]
# ### **Положение данных**
#
# Для каждого числового признака вычислите:
#
# - минимум (min);
# - максимум (max);
# - 1-й, 2-й и 3-й квартили (quantile).
#
# Сгруппируйте всё в таблицу.
# Сделайте вывод: есть ли признаки, которые сильно растянуты вдоль оси.

# %%
min_vals = df.min(numeric_only=True)
max_vals = df.max(numeric_only=True) # допишите код
q1_vals = df.quantile(0.25, numeric_only=True)
q2_vals = df.quantile(0.5, numeric_only=True) # допишите код
q3_vals = df.quantile(0.75, numeric_only=True)# допишите код

position_summary = pd.DataFrame({
    "Минимум": min_vals,
    "1 квартиль (25%)": q1_vals, # допишите код
    "2 квартиль (50%, медиана)": q2_vals,
    "3 квартиль (75%)": q3_vals, # допишите код
    "Максимум": max_vals
})

position_summary
# Out:
#                                            Минимум  1 квартиль (25%)  \
# Возраст алког                             6.000000         18.000000
# Работа                                    0.000000          0.000000
# Переломы                                  0.000000          0.000000
# Время пробуждения                         0.000000          6.000000
# ЛПВП                                     -0.680000          0.850000
# Выход на пенсию                           0.000000          0.000000
# Холестерин                                3.600000          4.500000
# Артериальная гипертония                   0.000000          0.000000
# Триглицериды                              0.210000          0.860000
# Гепатит                                   0.000000          0.000000
# Сахарный диабет                           0.000000          0.000000
# Пол                                       0.000000          0.000000
# Спорт, клубы                              0.000000          0.000000
# Семья                                     2.032866        124.091093
# Частота пасс кур                          0.000000          0.000000
# Возраст курения                           5.000000         20.000000
# Травмы за год                             0.000000          0.000000
# Регулярный прием лекарственных средств    0.000000          0.000000
# Национальность                            1.004157        895.020093
# Алкоголь                                155.000909        163.048523
# Глюкоза плазмы натощак                    1.850000          4.750000
# Абдоминальное ожирение, см               59.100000         68.300000
# Сон после обеда                           0.000000          0.000000
# Время засыпания                           0.000000         10.000000
# Хроническое заболевание легких            0.000000          0.000000
# Сигарет в день                            0.000000          0.000000
# Образование                               2.000000          4.000000
# Индекс массы тела, кг/м^2                18.000000         24.200000
# Религия                                  24.012056        799.009540
# Профессия                                 5.048727         80.073907
# ССЗ                                       0.000000          0.000000
# Продолжительность сна                     0.000000          7.000000
#
#                                         2 квартиль (50%, медиана)  \
# Возраст алког                                           20.000000
# Работа                                                   1.000000
# Переломы                                                 0.000000
# Время пробуждения                                        7.000000
# ЛПВП                                                     1.110000
# Выход на пенсию                                          0.000000
# Холестерин                                               5.200000
# Артериальная гипертония                                  0.000000
# Триглицериды                                             1.480000
# Гепатит                                                  0.000000
# Сахарный диабет                                          0.000000
# Пол                                                      1.000000
# Спорт, клубы                                             0.000000
# Семья                                                  559.014866
# Частота пасс кур                                         0.000000
# Возраст курения                                         90.000000
# Травмы за год                                            0.000000
# Регулярный прием лекарственных средств                   1.000000
# Национальность                                         895.048785
# Алкоголь                                               631.023829
# Глюкоза плазмы натощак                                   6.000000
# Абдоминальное ожирение, см                              81.400000
# Сон после обеда                                          0.000000
# Время засыпания                                         11.000000
# Хроническое заболевание легких                           0.000000
# Сигарет в день                                           0.000000
# Образование                                              4.000000
# Индекс массы тела, кг/м^2                               27.600000
# Религия                                                799.040754
# Профессия                                              123.007116
# ССЗ                                                      1.000000
# Продолжительность сна                                    8.000000
#
#                                         3 квартиль (75%)    Максимум
# Возраст алког                                  25.000000   90.000000
# Работа                                          1.000000    1.000000
# Переломы                                        1.000000    1.000000
# Время пробуждения                               8.000000   12.000000
# ЛПВП                                            1.340000    1.790000
# Выход на пенсию                                 1.000000    1.000000
# Холестерин                                      7.300000    9.200000
# Артериальная гипертония                         1.000000    1.000000
# Триглицериды                                    2.690000   14.300000
# Гепатит                                         0.000000    1.000000
# Сахарный диабет                                 0.000000    1.000000
# Пол                                             1.000000    1.000000
# Спорт, клубы                                    0.000000    1.000000
# Семья                                         559.057344  559.099972
# Частота пасс кур                                0.000000    5.000000
# Возраст курения                                90.000000   90.000000
# Травмы за год                                   0.000000    1.000000
# Регулярный прием лекарственных средств          1.000000    1.000000
# Национальность                                895.073743  895.099941
# Алкоголь                                      631.060821  631.099879
# Глюкоза плазмы натощак                          7.880000   25.830000
# Абдоминальное ожирение, см                     90.300000  110.700000
# Сон после обеда                                 0.000000    1.000000
# Время засыпания                                12.000000   15.000000
# Хроническое заболевание легких                  0.000000    1.000000
# Сигарет в день                                 10.000000   40.000000
# Образование                                     5.000000    5.000000
# Индекс массы тела, кг/м^2                      32.300000   37.000000
# Религия                                       799.068772  799.099835
# Профессия                                     136.086466  224.099724
# ССЗ                                             1.000000    1.000000
# Продолжительность сна                           9.000000   19.000000

# %% [markdown]
# **Выводы (дописать):**
#
# По минимумам, квартилям и максимумам видно, что несколько признаков имеют очень широкий диапазон значений и сильно растянуты вдоль оси. Это в первую очередь кодированные категориальные переменные:национальность, религия, профессия и семья и поведенческие показатели:время засыпания, возраст курения
#
# Бинарные признаки (0/1) — самые компактные и не имеют растяжения.
#
# В целом, признаки с большим размахом требуют масштабирования перед построением моделей, чтобы их диапазон не доминировал над остальными переменными.

# %% [markdown]
# # Корреляция и Линейная регрессия

# %% [markdown]
# ## Корреляция

# %% [markdown]
# **Корреляция** — это статистическая мера, показывающая, насколько сильно и в каком направлении связаны две количественные переменные.
#
# Если при увеличении одной переменной другая тоже увеличивается — связь положительная; если уменьшается — отрицательная.
#
# Коэффициент корреляции обозначается **r** и принимает значения от **–1 до 1**:
#
# | Значение r | Интерпретация связи |
# |-------------|--------------------|
# | r ≈ 1 | Сильная положительная связь (при росте X растёт Y) |
# | r ≈ 0 | Связь отсутствует |
# | r ≈ –1 | Сильная отрицательная связь (при росте X уменьшается Y) |
#
#
# **Виды корреляции:**
# - **Пирсон** — измеряет *линейную* зависимость между переменными;
# - **Спирмен** — оценивает, растут ли переменные “вместе” в целом, даже если зависимость не по прямой линии.
#
# **Важно:** корреляция показывает лишь *совместное изменение переменных*, но не доказывает причинно-следственную связь.

# %% [markdown]
# ## Линейная регрессия

# %% [markdown]
# **Линейная регрессия** — один из самых простых и распространённых методов анализа данных.
# Её цель — **предсказать значение одной переменной (целевой)** на основе значений других переменных (признаков).
#
# Математическая модель имеет вид:
#
# **y = b₀ + b₁·x₁ + b₂·x₂ + ... + bₙ·xₙ**
#
# где
# - **y** — предсказываемое значение (целевая переменная);
# - **x₁, x₂, …, xₙ** — признаки (факторы, влияющие на результат);
# - **b₀** — свободный член (точка пересечения с осью Y);
# - **bᵢ** — коэффициенты регрессии, показывающие силу и направление влияния каждого признака.
#
# ---
#
# Интерпретация коэффициентов:
#
# - Если **bᵢ > 0** → при увеличении признака значение цели **растёт**.
# - Если **bᵢ < 0** → при увеличении признака значение цели **уменьшается**.
# - Чем больше по модулю **bᵢ**, тем сильнее влияние признака.
#
# ---
#
# Пример уравнения регрессии:
#
# **Холестерин = 120 + 1.5 · Возраст + 2.8 · ИМТ**
#
# Интерпретация коэффициентов:
#
# - если **возраст увеличивается на 1 год**, уровень холестерина в среднем повышается на **1.5 единицы**;
# - если **ИМТ увеличивается на 1 пункт**, уровень холестерина растёт примерно на **2.8 единицы**;
# - число **120** — это базовое значение холестерина у пациента с низким ИМТ и минимальным возрастом
#   (условная точка отсчёта, от которой модель строит прогноз).
#
# Такое уравнение помогает понять вклад каждого признака в итоговый показатель и увидеть,
# как изменения входных переменных отражаются на прогнозе модели.
#
# ---
#
# Виды линейной регрессии:
#
# 1. **Простая линейная регрессия** — один признак → одна цель
#    `y = b₀ + b₁·x`
# 2. **Множественная линейная регрессия** — несколько признаков → одна цель
#    `y = b₀ + b₁·x₁ + b₂·x₂ + ... + bₙ·xₙ`
#
# ---
#
# Почему линейная регрессия важна:
#
# - помогает понять, **какие признаки влияют** на результат;
# - даёт **интерпретируемую модель**, где каждый коэффициент имеет смысл;
# - позволяет **делать прогнозы** и **оценивать взаимосвязи** в данных.
#
# ---

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ### Корреляция

# %% [markdown]
# Шаг 1. Рассчитайте матрицу корреляции методом Пирсона (`df.corr(method="pearson")`).

# %%
corr_pearson = df.corr(numeric_only=True, method="pearson" ) # добавить код
corr_pearson.round(2)
# Out:
#                                         Возраст алког  Работа  Переломы  \
# Возраст алког                                    1.00   -0.09     -0.04
# Работа                                          -0.09    1.00     -0.06
# Переломы                                        -0.04   -0.06      1.00
# Время пробуждения                               -0.09   -0.16     -0.01
# ЛПВП                                             0.04    0.07     -0.15
# Выход на пенсию                                  0.08   -0.74      0.07
# Холестерин                                       0.08   -0.19      0.11
# Артериальная гипертония                          0.04   -0.19      0.08
# Триглицериды                                     0.08   -0.13      0.08
# Гепатит                                         -0.06    0.02      0.03
# Сахарный диабет                                  0.00   -0.14      0.01
# Пол                                              0.21   -0.18     -0.13
# Спорт, клубы                                    -0.00    0.02     -0.01
# Семья                                           -0.11    0.03      0.03
# Частота пасс кур                                 0.03    0.06     -0.04
# Возраст курения                                  0.23   -0.09     -0.06
# Травмы за год                                   -0.01    0.00      0.17
# Регулярный прием лекарственных средств           0.05   -0.21      0.04
# Национальность                                   0.00   -0.02      0.01
# Алкоголь                                        -0.62    0.15      0.03
# Глюкоза плазмы натощак                          -0.01   -0.08      0.04
# Абдоминальное ожирение, см                      -0.04   -0.11      0.17
# Сон после обеда                                 -0.02   -0.15      0.05
# Время засыпания                                  0.03   -0.04      0.01
# Хроническое заболевание легких                   0.00    0.00      0.07
# Сигарет в день                                  -0.21    0.08      0.07
# Образование                                     -0.04    0.14     -0.08
# Индекс массы тела, кг/м^2                        0.06   -0.19      0.12
# Религия                                          0.04   -0.03     -0.02
# Профессия                                        0.04    0.08     -0.08
# ССЗ                                              0.04   -0.22      0.12
# Продолжительность сна                           -0.11   -0.11     -0.02
#
#                                         Время пробуждения  ЛПВП  \
# Возраст алког                                       -0.09  0.04
# Работа                                              -0.16  0.07
# Переломы                                            -0.01 -0.15
# Время пробуждения                                    1.00  0.04
# ЛПВП                                                 0.04  1.00
# Выход на пенсию                                      0.10 -0.09
# Холестерин                                          -0.01 -0.45
# Артериальная гипертония                              0.02 -0.55
# Триглицериды                                        -0.02 -0.78
# Гепатит                                              0.02  0.02
# Сахарный диабет                                      0.01 -0.30
# Пол                                                  0.04  0.38
# Спорт, клубы                                         0.01  0.13
# Семья                                               -0.01 -0.03
# Частота пасс кур                                    -0.02  0.07
# Возраст курения                                     -0.01  0.25
# Травмы за год                                       -0.00 -0.00
# Регулярный прием лекарственных средств               0.03 -0.22
# Национальность                                      -0.03  0.01
# Алкоголь                                             0.06  0.02
# Глюкоза плазмы натощак                              -0.04 -0.25
# Абдоминальное ожирение, см                          -0.00 -0.67
# Сон после обеда                                     -0.01 -0.10
# Время засыпания                                      0.30 -0.03
# Хроническое заболевание легких                      -0.10 -0.03
# Сигарет в день                                      -0.05 -0.28
# Образование                                          0.05  0.17
# Индекс массы тела, кг/м^2                           -0.03 -0.57
# Религия                                              0.06  0.01
# Профессия                                           -0.02  0.13
# ССЗ                                                  0.00 -0.58
# Продолжительность сна                                0.67  0.06
#
#                                         Выход на пенсию  Холестерин  \
# Возраст алког                                      0.08        0.08
# Работа                                            -0.74       -0.19
# Переломы                                           0.07        0.11
# Время пробуждения                                  0.10       -0.01
# ЛПВП                                              -0.09       -0.45
# Выход на пенсию                                    1.00        0.22
# Холестерин                                         0.22        1.00
# Артериальная гипертония                            0.23        0.73
# Триглицериды                                       0.14        0.44
# Гепатит                                           -0.05        0.01
# Сахарный диабет                                    0.18        0.17
# Пол                                                0.16        0.09
# Спорт, клубы                                       0.02       -0.00
# Семья                                             -0.05       -0.06
# Частота пасс кур                                  -0.04       -0.01
# Возраст курения                                    0.15        0.07
# Травмы за год                                     -0.00        0.01
# Регулярный прием лекарственных средств             0.22        0.41
# Национальность                                     0.07       -0.01
# Алкоголь                                          -0.07       -0.07
# Глюкоза плазмы натощак                             0.09        0.35
# Абдоминальное ожирение, см                         0.15        0.59
# Сон после обеда                                    0.11        0.04
# Время засыпания                                    0.01       -0.07
# Хроническое заболевание легких                    -0.00        0.07
# Сигарет в день                                    -0.13       -0.05
# Образование                                       -0.12       -0.05
# Индекс массы тела, кг/м^2                          0.22        0.62
# Религия                                            0.05        0.06
# Профессия                                         -0.06       -0.05
# ССЗ                                                0.25        0.79
# Продолжительность сна                              0.08        0.04
#
#                                         Артериальная гипертония  Триглицериды  \
# Возраст алког                                              0.04          0.08
# Работа                                                    -0.19         -0.13
# Переломы                                                   0.08          0.08
# Время пробуждения                                          0.02         -0.02
# ЛПВП                                                      -0.55         -0.78
# Выход на пенсию                                            0.23          0.14
# Холестерин                                                 0.73          0.44
# Артериальная гипертония                                    1.00          0.56
# Триглицериды                                               0.56          1.00
# Гепатит                                                   -0.03         -0.01
# Сахарный диабет                                            0.21          0.13
# Пол                                                        0.11          0.10
# Спорт, клубы                                               0.04          0.00
# Семья                                                     -0.05         -0.07
# Частота пасс кур                                           0.02          0.01
# Возраст курения                                            0.08          0.07
# Травмы за год                                              0.04          0.03
# Регулярный прием лекарственных средств                     0.42          0.27
# Национальность                                             0.02          0.04
# Алкоголь                                                  -0.04         -0.06
# Глюкоза плазмы натощак                                     0.42          0.25
# Абдоминальное ожирение, см                                 0.67          0.41
# Сон после обеда                                            0.05          0.00
# Время засыпания                                           -0.00          0.01
# Хроническое заболевание легких                             0.05          0.03
# Сигарет в день                                            -0.08         -0.05
# Образование                                               -0.06         -0.07
# Индекс массы тела, кг/м^2                                  0.70          0.43
# Религия                                                    0.08          0.07
# Профессия                                                 -0.05         -0.03
# ССЗ                                                        0.88          0.56
# Продолжительность сна                                      0.02         -0.03
#
#                                         Гепатит  ...  Сон после обеда  \
# Возраст алког                             -0.06  ...            -0.02
# Работа                                     0.02  ...            -0.15
# Переломы                                   0.03  ...             0.05
# Время пробуждения                          0.02  ...            -0.01
# ЛПВП                                       0.02  ...            -0.10
# Выход на пенсию                           -0.05  ...             0.11
# Холестерин                                 0.01  ...             0.04
# Артериальная гипертония                   -0.03  ...             0.05
# Триглицериды                              -0.01  ...             0.00
# Гепатит                                    1.00  ...            -0.01
# Сахарный диабет                           -0.01  ...             0.17
# Пол                                        0.00  ...            -0.06
# Спорт, клубы                               0.01  ...            -0.06
# Семья                                     -0.00  ...             0.03
# Частота пасс кур                          -0.00  ...            -0.06
# Возраст курения                           -0.05  ...            -0.05
# Травмы за год                             -0.02  ...             0.02
# Регулярный прием лекарственных средств     0.02  ...             0.04
# Национальность                             0.04  ...             0.02
# Алкоголь                                   0.04  ...            -0.04
# Глюкоза плазмы натощак                    -0.04  ...             0.01
# Абдоминальное ожирение, см                -0.04  ...             0.11
# Сон после обеда                           -0.01  ...             1.00
# Время засыпания                            0.00  ...             0.02
# Хроническое заболевание легких             0.03  ...             0.03
# Сигарет в день                             0.02  ...             0.06
# Образование                               -0.01  ...            -0.11
# Индекс массы тела, кг/м^2                 -0.03  ...             0.06
# Религия                                    0.00  ...             0.01
# Профессия                                 -0.05  ...            -0.06
# ССЗ                                       -0.03  ...             0.06
# Продолжительность сна                      0.02  ...            -0.02
#
#                                         Время засыпания  \
# Возраст алког                                      0.03
# Работа                                            -0.04
# Переломы                                           0.01
# Время пробуждения                                  0.30
# ЛПВП                                              -0.03
# Выход на пенсию                                    0.01
# Холестерин                                        -0.07
# Артериальная гипертония                           -0.00
# Триглицериды                                       0.01
# Гепатит                                            0.00
# Сахарный диабет                                   -0.01
# Пол                                                0.02
# Спорт, клубы                                      -0.01
# Семья                                             -0.05
# Частота пасс кур                                  -0.01
# Возраст курения                                   -0.07
# Травмы за год                                      0.07
# Регулярный прием лекарственных средств            -0.06
# Национальность                                     0.02
# Алкоголь                                          -0.01
# Глюкоза плазмы натощак                            -0.04
# Абдоминальное ожирение, см                        -0.03
# Сон после обеда                                    0.02
# Время засыпания                                    1.00
# Хроническое заболевание легких                     0.03
# Сигарет в день                                     0.05
# Образование                                        0.06
# Индекс массы тела, кг/м^2                         -0.02
# Религия                                            0.05
# Профессия                                          0.05
# ССЗ                                               -0.04
# Продолжительность сна                             -0.50
#
#                                         Хроническое заболевание легких  \
# Возраст алког                                                     0.00
# Работа                                                            0.00
# Переломы                                                          0.07
# Время пробуждения                                                -0.10
# ЛПВП                                                             -0.03
# Выход на пенсию                                                  -0.00
# Холестерин                                                        0.07
# Артериальная гипертония                                           0.05
# Триглицериды                                                      0.03
# Гепатит                                                           0.03
# Сахарный диабет                                                  -0.05
# Пол                                                              -0.00
# Спорт, клубы                                                      0.03
# Семья                                                            -0.01
# Частота пасс кур                                                 -0.02
# Возраст курения                                                  -0.07
# Травмы за год                                                     0.06
# Регулярный прием лекарственных средств                            0.06
# Национальность                                                   -0.02
# Алкоголь                                                         -0.04
# Глюкоза плазмы натощак                                            0.06
# Абдоминальное ожирение, см                                        0.03
# Сон после обеда                                                   0.03
# Время засыпания                                                   0.03
# Хроническое заболевание легких                                    1.00
# Сигарет в день                                                    0.08
# Образование                                                      -0.07
# Индекс массы тела, кг/м^2                                        -0.00
# Религия                                                          -0.01
# Профессия                                                        -0.03
# ССЗ                                                               0.08
# Продолжительность сна                                            -0.11
#
#                                         Сигарет в день  Образование  \
# Возраст алког                                    -0.21        -0.04
# Работа                                            0.08         0.14
# Переломы                                          0.07        -0.08
# Время пробуждения                                -0.05         0.05
# ЛПВП                                             -0.28         0.17
# Выход на пенсию                                  -0.13        -0.12
# Холестерин                                       -0.05        -0.05
# Артериальная гипертония                          -0.08        -0.06
# Триглицериды                                     -0.05        -0.07
# Гепатит                                           0.02        -0.01
# Сахарный диабет                                  -0.04        -0.09
# Пол                                              -0.52         0.11
# Спорт, клубы                                     -0.05         0.16
# Семья                                             0.11         0.02
# Частота пасс кур                                 -0.09        -0.04
# Возраст курения                                  -0.76         0.11
# Травмы за год                                    -0.03         0.03
# Регулярный прием лекарственных средств           -0.09        -0.01
# Национальность                                   -0.09         0.07
# Алкоголь                                          0.09         0.06
# Глюкоза плазмы натощак                            0.01         0.00
# Абдоминальное ожирение, см                        0.13        -0.08
# Сон после обеда                                   0.06        -0.11
# Время засыпания                                   0.05         0.06
# Хроническое заболевание легких                    0.08        -0.07
# Сигарет в день                                    1.00        -0.14
# Образование                                      -0.14         1.00
# Индекс массы тела, кг/м^2                        -0.06        -0.07
# Религия                                          -0.10         0.04
# Профессия                                        -0.16         0.40
# ССЗ                                               0.05        -0.09
# Продолжительность сна                            -0.08        -0.00
#
#                                         Индекс массы тела, кг/м^2  Религия  \
# Возраст алког                                                0.06     0.04
# Работа                                                      -0.19    -0.03
# Переломы                                                     0.12    -0.02
# Время пробуждения                                           -0.03     0.06
# ЛПВП                                                        -0.57     0.01
# Выход на пенсию                                              0.22     0.05
# Холестерин                                                   0.62     0.06
# Артериальная гипертония                                      0.70     0.08
# Триглицериды                                                 0.43     0.07
# Гепатит                                                     -0.03     0.00
# Сахарный диабет                                              0.17     0.04
# Пол                                                         -0.06     0.17
# Спорт, клубы                                                 0.04    -0.01
# Семья                                                       -0.04    -0.03
# Частота пасс кур                                             0.01    -0.05
# Возраст курения                                              0.13     0.10
# Травмы за год                                                0.06     0.05
# Регулярный прием лекарственных средств                       0.38     0.08
# Национальность                                              -0.01     0.28
# Алкоголь                                                    -0.10    -0.03
# Глюкоза плазмы натощак                                       0.33     0.00
# Абдоминальное ожирение, см                                   0.74    -0.02
# Сон после обеда                                              0.06     0.01
# Время засыпания                                             -0.02     0.05
# Хроническое заболевание легких                              -0.00    -0.01
# Сигарет в день                                              -0.06    -0.10
# Образование                                                 -0.07     0.04
# Индекс массы тела, кг/м^2                                    1.00     0.03
# Религия                                                      0.03     1.00
# Профессия                                                   -0.02     0.05
# ССЗ                                                          0.75     0.06
# Продолжительность сна                                       -0.01     0.02
#
#                                         Профессия   ССЗ  Продолжительность сна
# Возраст алког                                0.04  0.04                  -0.11
# Работа                                       0.08 -0.22                  -0.11
# Переломы                                    -0.08  0.12                  -0.02
# Время пробуждения                           -0.02  0.00                   0.67
# ЛПВП                                         0.13 -0.58                   0.06
# Выход на пенсию                             -0.06  0.25                   0.08
# Холестерин                                  -0.05  0.79                   0.04
# Артериальная гипертония                     -0.05  0.88                   0.02
# Триглицериды                                -0.03  0.56                  -0.03
# Гепатит                                     -0.05 -0.03                   0.02
# Сахарный диабет                             -0.03  0.23                   0.01
# Пол                                          0.17  0.07                   0.02
# Спорт, клубы                                 0.09  0.04                   0.02
# Семья                                       -0.03 -0.05                   0.03
# Частота пасс кур                            -0.03 -0.00                  -0.01
# Возраст курения                              0.13  0.03                   0.05
# Травмы за год                               -0.01  0.03                  -0.05
# Регулярный прием лекарственных средств       0.00  0.46                   0.07
# Национальность                               0.05  0.01                  -0.04
# Алкоголь                                     0.06 -0.06                   0.06
# Глюкоза плазмы натощак                      -0.01  0.41                  -0.01
# Абдоминальное ожирение, см                  -0.11  0.73                   0.02
# Сон после обеда                             -0.06  0.06                  -0.02
# Время засыпания                              0.05 -0.04                  -0.50
# Хроническое заболевание легких              -0.03  0.08                  -0.11
# Сигарет в день                              -0.16  0.05                  -0.08
# Образование                                  0.40 -0.09                  -0.00
# Индекс массы тела, кг/м^2                   -0.02  0.75                  -0.01
# Религия                                      0.05  0.06                   0.02
# Профессия                                    1.00 -0.06                  -0.06
# ССЗ                                         -0.06  1.00                   0.03
# Продолжительность сна                       -0.06  0.03                   1.00
#
# [32 rows x 32 columns]

# %% [markdown]
# **Выводы (дописать):**

# %% [markdown]
# Шаг 2. Визуализируйте корреляции с помощью графика `seaborn.heatmap`

# %%
plt.figure(figsize=(20,16))
sns.heatmap(data = corr_pearson, cmap='coolwarm', center=0, annot=True, fmt=".1f") # добавьте после "data =" название матрицы корреляции из предыдущего кода
plt.title("Корреляционная матрица (Пирсон)")
plt.show()

# %% [markdown]
# Шаг 3. Проанализируйте связи с целевой переменное (ЛПВП), постройте график barplot с помощью `seaborn.barplot`. С помощью параметра `ascending=False` в функции `sort_values` переделайте график, чтобы расположить столбцы в порядке убывания.

# %%
target_corr = corr_pearson["ЛПВП"].drop("ЛПВП").sort_values(ascending=False) # допиши код
sns.barplot(x=target_corr.values, y=target_corr.index)
plt.title("Связь признаков с целевой переменной")
plt.xlabel("Коэффициент корреляции")
plt.ylabel("ССЗ")
plt.show()

# %% [markdown]
# **Выводы (дописать):**
#
# Сильные положительные связи:
#
# - пол — наиболее высокая положительная корреляция с целевой переменной.
#
# - возраст курения - также высокая зависимость: чем раньше начал курить, тем больше риск ССЗ
#
# Сильные отрицательные связи:
#
# - триглицериды — самая сильная отрицательная корреляция.
#
# - абдоминальное ожирение — также выраженная отрицательная зависимость: чем больше окружность живота, тем ниже значение целевой переменной.

# %% [markdown]
# Шаг 4. Постройте scatter-график с линией тренда (`seaborn.regplot`) для признака с самой сильной корреляцией с признаком "ЛПВП", сделайте вывод о характере связи.
# По оси y возьмите признак "ЛПВП", а по оси x признак с самой высокой корреляцией с "ЛПВП" (подсказка: корреляция отрицательная).

# %%
sns.regplot(corr_pearson, y="ЛПВП", x = "Триглицериды" ) # добавьте название датасета, x, y
plt.title("Линейная зависимость между триглицеридами и ЛПВП")
plt.show()

# %% [markdown]
# **Выводы (дописать):**
#
# На графике видна ярко выраженная отрицательная зависимость между уровнем триглицеридов и ЛПВП

# %% [markdown]
# ### Линейная регрессия

# %% [markdown]
# Шаг 1. Создайте список features

# %%
features = ["Триглицериды"] # добавьте 'Триглицериды'

target = "ЛПВП" # целевая переменная

# %% [markdown]
# Шаг 2. Разделите данные на train/test с помошью `train_test_split`.

# %%
X = df[features].copy()
y = df[target].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42 # random_state=42 для того, чтобы при повторном запуске модели получить тот же результат
)

# %% [markdown]
# Шаг 3. Нормализацизуйте признаки используя `StandardScaler`: обучите scaler на train, примените к train и test, сохраните преобразованные данные.

# %%
scaler = StandardScaler()        # создаём объект стандартизации (вычитает среднее, делит на std)
X_train_scaled = scaler.fit_transform(X_train)   # обучаем scaler на train и сразу масштабируем train

X_test_scaled = scaler.transform(X_test)         # масштабируем test теми же параметрами (mean/std)

X_train_s = pd.DataFrame(X_train_scaled, columns=features, index=X_train.index)
# превращаем масштабированный train в DataFrame с теми же колонками и индексами

X_test_s = pd.DataFrame(X_test_scaled,  columns=features, index=X_test.index)
# то же самое для test

# %% [markdown]
# Шаг 4. Обучите модель `LinearRegression()` и получите прогноз на тестовых данных.

# %%
lin = LinearRegression()
lin.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Шаг 5. Выведите уравнение модели, получая коэффициенты `model.coef_` и свободный член `model.intercept_`.

# %%
# Свободный член и коэффициенты
b0 = lin.intercept_
coefs = pd.Series(lin.coef_, index=features)

print("Свободный член (b0):", round(b0, 3))
print()

print("Коэффициенты модели:")
display(coefs.to_frame("Коэффициент").round(3))

# Формирование уравнения модели
terms = [f"{coefs[f]:.3f}·{f}" for f in features]
equation = f"{target} = {b0:.3f} + " + " + ".join(terms)

print("\nУравнение модели:\n")
print(equation)
# Out:
# Свободный член (b0): 1.068
#
# Коэффициенты модели:
#               Коэффициент
# Триглицериды        -0.28
# Уравнение модели:
#
# ЛПВП = 1.068 + -0.280·Триглицериды

# %% [markdown]
# Шаг 6. Посчитайте метрики оценки качества (R², MAE, RMSE). Сделайте вывод о качестве модели.

# %%
# Предсказания
y_pred = lin.predict(X_test_s)

# Метрики
r2   = r2_score(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f"R²   = {r2:.3f}")
print(f"MAE  = {mae:.3f}")
print(f"MSE  = {mse:.3f}")
print(f"RMSE = {rmse:.3f}")
print(f"MAPE = {mape:.3f}")
# Out:
# R²   = 0.671
# MAE  = 0.182
# MSE  = 0.048
# RMSE = 0.219
# MAPE = 0.283

# %% [markdown]
# **Выводы:**
# - R² (коэффициент детерминации) Показывает, какую долю вариации целевой переменной объясняет модель. 0.671 → модель объясняет 67.1% изменений ЛПВП.
# - MAE 0.182 → в среднем модель ошибается на 0.18 единицы ЛПВП.
# - MSE средний квадрат ошибки. Чувствителен к большим отклонениям.
# 0.048 → небольшие крупные ошибки, модель стабильная.
# - RMSE — ошибка в тех же единицах, что и целевая переменная.
# 0.219 → средняя ошибка примерно 0.22 ЛПВП.
# - MAPE... 0,283 - показывает разницу между фактическим и предсказанным значением

# %% [markdown]
# ## *Необязательное задание:*
#
# Попробуйте построить две разные модели регрессии для мужчин и женщин, то есть отдельно для `df_0 = df[df['Пол'] == 0]` и `df_1 = df[df['Пол'] == 1]`. Как это повлияло на качество результата?

# %% [markdown]
# Для `df_0 = df[df['Пол'] == 0]`:

# %%
features = ['Триглицериды']

target = "ЛПВП"

df_0 = df[df['Пол'] == 0]

X = df_0[features].copy()
y = df_0[target].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

scaler = StandardScaler()        # создаём объект стандартизации (вычитает среднее, делит на std)
X_train_scaled = scaler.fit_transform(X_train)   # обучаем scaler на train и сразу масштабируем train

X_test_scaled = scaler.transform(X_test)         # масштабируем test теми же параметрами (mean/std)

X_train_s = pd.DataFrame(X_train_scaled, columns=features, index=X_train.index)
# превращаем масштабированный train в DataFrame с теми же колонками и индексами

X_test_s = pd.DataFrame(X_test_scaled,  columns=features, index=X_test.index)
# продолжите код

lin = LinearRegression()
lin.fit(X_train_s, y_train)

# Свободный член и коэффициенты
b0 = lin.intercept_
coefs = pd.Series(lin.coef_, index=features)

print("Свободный член (b0):", round(b0, 3))
print()

print("Коэффициенты модели:")
display(coefs.to_frame("Коэффициент").round(3))

# Формирование уравнения модели
terms = [f"{coefs[f]:.3f}·{f}" for f in features]
equation = f"{target} = {b0:.3f} + " + " + ".join(terms)

print("\nУравнение модели:\n")
print(equation)

# Предсказания
y_pred = lin.predict(X_test_s)

# Метрики
r2   = r2_score(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f"R²   = {r2:.3f}")
print(f"MAE  = {mae:.3f}")
print(f"MSE  = {mse:.3f}")
print(f"RMSE = {rmse:.3f}")
print(f"MAPE = {mape:.3f}")
# Out:
# Свободный член (b0): 0.854
#
# Коэффициенты модели:
#               Коэффициент
# Триглицериды       -0.261
# Уравнение модели:
#
# ЛПВП = 0.854 + -0.261·Триглицериды
# R²   = 0.719
# MAE  = 0.132
# MSE  = 0.025
# RMSE = 0.158
# MAPE = 0.182

# %% [markdown]
# Для `df_1 = df[df['Пол'] == 1]`:

# %%
features = ['Триглицериды']

target = "ЛПВП"

df_1 = df[df['Пол'] == 1]

X = df_1[features].copy()
y = df_1[target].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)
# продолжите код
X = df_0[features].copy()
y = df_0[target].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)

scaler = StandardScaler()        # создаём объект стандартизации (вычитает среднее, делит на std)
X_train_scaled = scaler.fit_transform(X_train)   # обучаем scaler на train и сразу масштабируем train

X_test_scaled = scaler.transform(X_test)         # масштабируем test теми же параметрами (mean/std)

X_train_s = pd.DataFrame(X_train_scaled, columns=features, index=X_train.index)
# превращаем масштабированный train в DataFrame с теми же колонками и индексами

X_test_s = pd.DataFrame(X_test_scaled,  columns=features, index=X_test.index)
# продолжите код

lin = LinearRegression()
lin.fit(X_train_s, y_train)

# Свободный член и коэффициенты
b0 = lin.intercept_
coefs = pd.Series(lin.coef_, index=features)

print("Свободный член (b0):", round(b0, 3))
print()

print("Коэффициенты модели:")
display(coefs.to_frame("Коэффициент").round(3))

# Формирование уравнения модели
terms = [f"{coefs[f]:.3f}·{f}" for f in features]
equation = f"{target} = {b0:.3f} + " + " + ".join(terms)

print("\nУравнение модели:\n")
print(equation)

# Предсказания
y_pred = lin.predict(X_test_s)

# Метрики
r2   = r2_score(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f"R²   = {r2:.3f}")
print(f"MAE  = {mae:.3f}")
print(f"MSE  = {mse:.3f}")
print(f"RMSE = {rmse:.3f}")
print(f"MAPE = {mape:.3f}")
# Out:
# Свободный член (b0): 0.854
#
# Коэффициенты модели:
#               Коэффициент
# Триглицериды       -0.261
# Уравнение модели:
#
# ЛПВП = 0.854 + -0.261·Триглицериды
# R²   = 0.719
# MAE  = 0.132
# MSE  = 0.025
# RMSE = 0.158
# MAPE = 0.182
